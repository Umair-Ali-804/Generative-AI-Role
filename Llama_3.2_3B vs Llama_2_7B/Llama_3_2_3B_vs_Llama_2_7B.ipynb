# %%
# !pip install langchain_community langchain_classic langchain_core langchain_text_splitters langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

from langchain_community.embeddings import SentenceTransformerEmbeddings

from langchain_core.prompts import PromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains import create_retrieval_chain

# %%
BASE_URL = "https://openrouter.ai/api/v1"
OPENROUTER_API_KEY = "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"
MODEL_1 = "meta-llama/llama-3.2-3b-instruct:free"
MODEL_2 ="meta-llama/llama-2-7b-instruct:free"

# %%
prompt_template='''
Your are a powerful AI assistant

Your task is to provide valid information
user_query:{query}
'''

# %%
llm = ChatOpenAI(
    model=MODEL_1,
    openai_api_key=OPENROUTER_API_KEY,
    openai_api_base=BASE_URL,
    temperature=0.7,
    max_tokens=1024,
    default_headers={
        "HTTP-Referer": "https://company-chatbot.local",
        "X-Title": "Multi-Agent System",
    }
)

# %%
def run_llm(model,template,query):
  prompt=PromptTemplate(
      input_variables=["query"],
      template=template
  )


  final_input=prompt.format(query=query)
  response=llm.invoke(final_input).content
  print(response)

# %%
query="give me 500 words explaination on pakisan neigubers"

# %%
run_llm(MODEL_1,prompt_template,query)
# Out:
# ### **Pakistan’s Neighbors: A Comprehensive Overview**
#
# Pakistan, located in South Asia, shares its borders with four countries: **India, Afghanistan, Iran, and China**. Each neighbor plays a significant role in Pakistan’s geopolitical, economic, and security landscape. Below is a detailed explanation of Pakistan’s relations with its neighbors.
#
# ---
#
# ### **1. India (East & Northeast Border)**
# India is Pakistan’s largest and most strategically important neighbor, with a **3,323 km** border, including the **Line of Control (LoC)** in Kashmir. The relationship between the two nations has been historically tense due to several key issues:
#
# - **Kashmir Dispute**: The primary conflict revolves around the region of **Jammu and Kashmir**, which both countries claim in full but control only parts of. Wars in **1947, 1965, 1971, and the 1999 Kargil conflict** have deepened mistrust.
# ...

# %%
llm = ChatOpenAI(
    model=MODEL_2,
    openai_api_key=OPENROUTER_API_KEY,
    openai_api_base=BASE_URL,
    temperature=0.7,
    max_tokens=1024,
    default_headers={
        "HTTP-Referer": "https://company-chatbot.local",
        "X-Title": "Multi-Agent System",
    }
)

# %%
run_llm(MODEL_2,prompt_template,query)
# Out:
# ### **Pakistan’s Neighbors: A Comprehensive Overview (500 Words)**
#
# Pakistan, located in South Asia, shares its borders with four countries: **India, Afghanistan, Iran, and China**. These neighboring nations play a crucial role in Pakistan’s geopolitical, economic, and security landscape. Below is a detailed explanation of Pakistan’s relations with each neighbor.
#
# #### **1. India (East & Northeast Border)**
# Pakistan and India share a **3,323 km** border, including the disputed **Line of Control (LoC)** in Kashmir. Their relationship has been historically tense due to:
# - **Kashmir Conflict**: Both nations claim Kashmir, leading to multiple wars (1947, 1965, 1971, and 1999 Kargil conflict).
# - **Cross-Border Terrorism**: Pakistan accuses India of supporting separatist movements, while India blames Pakistan for militant attacks.
# - **Trade & Diplomacy**: Despite tensions, trade exists, but political relations remain strained.
#
# ...
